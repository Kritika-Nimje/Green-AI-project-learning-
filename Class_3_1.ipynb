# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the dataset

df= pd.read_csv('appliance_energy.csv')

#Display the first few rows to understand the structure

print(df.head())
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
#check for missing values
print(df.isnull().sum())
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
#Features(independent variables) and target(dependent variable)
# Independent variables (Temperature)
X = df[['Temperature (°C)']]
# Dependent variable (Appliances)   
y = df['Energy Consumption (kWh)']

# %%
#slit the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Create a linear regression rmodel
model = LinearRegression()
# Train the model using the training sets
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions using the testing set
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1.98154974, 2.89901722, 2.90315114, 3.23188929, 2.89798016,
#        2.60759068, 2.16258824, 3.04765769, 2.67099539, 2.49076036,
#        3.18506324, 2.95299694, 2.2564649 , 2.00347712, 3.13545965,
#        2.68769348, 2.14164377, 2.42544632, 3.27865373, 2.67656155])

# %%
mse = mean_squared_error
print('Mean Squared Error:', mse(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print('R2 Score:', r2)
# Out:
# Mean Squared Error: 0.16750882603406914
# R2 Score: 0.5920734090562098

# %%
plt.scatter(X_test, y_test, color='black', label='Test Data')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predicted')
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.legend()
plt.title('Linear Regression Model')
plt.show()

# %%
import joblib
#save the model to the file 
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
